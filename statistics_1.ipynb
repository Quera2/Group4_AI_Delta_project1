# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# تحلیل‌های آماری</font>
# </h1>

# %%
#import_libraries

import matplotlib.pyplot as plt
import pandas  as pd
import scipy as sp
import numpy as np
import seaborn as sns 
from scipy.stats import shapiro
from sklearn import preprocessing
from scipy import stats
from scipy.stats import mannwhitneyu 
from random import sample 
from sklearn.preprocessing import power_transform

# %% [markdown]
# <h2 dir=rtl align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آمار توصیفی
# </font>
# </h2>
#
# <h3 dir=rtl  style="line-height:200%;font-family:vazir">
# <font face="vazir" size=4>
# 1 - توزیع اطلاعات خانوار (میزان تحصیلات، سن، بستگی با سرپرست، وضع فعاليت)
# </font>
# </h3>

# %%
data_401_urban = pd.read_excel('U1401.xlsx', sheet_name='R1401P1')
data_400_urban = pd.read_excel('U1400.xlsx', sheet_name='R1400P1')
data_99_urban = pd.read_excel('U99.xlsx', sheet_name='R99P1')
data_98_urban = pd.read_excel('U98.xlsx', sheet_name='R1399P1')

# %%
data_401_rural = pd.read_excel('R1401.xlsx', sheet_name='R1401P1')
data_400_rural = pd.read_excel('R1400.xlsx', sheet_name='R1400P1')
data_99_rural = pd.read_excel('R99.xlsx', sheet_name='R99P1')
data_98_rural = pd.read_excel('R98.xlsx', sheet_name='R98P1')

# %%
degree_401_urban= data_401_urban['degree'].dropna()
degree_400_urban= data_400_urban['degree'].dropna()
degree_99_urban= data_99_urban['degree'].dropna()
degree_98_urban= data_98_urban['degree'].dropna()
degree_401_rural= data_98_rural['degree'].dropna()
degree_400_rural= data_98_rural['degree'].dropna()
degree_99_rural= data_98_rural['degree'].dropna()
degree_98_rural= data_98_rural['degree'].dropna()

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# میزان تحصیلات
# </font>
# </h3>

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(18, 8))

# 1401_degree
axes[0][0].hist(degree_401_urban, label='urbun', alpha=.8, edgecolor='black')
axes[0][0].hist(degree_401_rural, label='rural', alpha=0.7, edgecolor='black')
axes[0][0].set_title('1401 Degrees')
axes[0][0].set_ylabel('number of people')
axes[0][0].grid(axis='y', alpha=0.75)
axes[0][0].legend(loc='upper right')
# 1400_degree
axes[0][1].hist(degree_400_urban, label='urbun', alpha=.8, edgecolor='black')
axes[0][1].hist(degree_400_rural, label='rural', alpha=0.7, edgecolor='black')
axes[0][1].set_title('1400 Degrees')
axes[0][1].set_ylabel('number of people')
axes[0][1].grid(axis='y', alpha=0.75)
axes[0][1].legend(loc='upper right')
# 99_degree
axes[1][0].hist(degree_99_urban, label='urbun', alpha=.8, edgecolor='black')
axes[1][0].hist(degree_99_rural, label='rural', alpha=0.7, edgecolor='black')
axes[1][0].set_title('99 Degrees')
axes[1][0].set_ylabel('number of people')
axes[1][0].grid(axis='y', alpha=0.75)
axes[1][0].legend(loc='upper right')
# 98_degree
axes[1][1].hist(degree_98_urban, label='urbun', alpha=.8, edgecolor='black')
axes[1][1].hist(degree_98_rural, label='rural', alpha=0.7, edgecolor='black')
axes[1][1].set_title('98 Degrees')
axes[1][1].set_ylabel('number of people')
axes[1][1].grid(axis='y', alpha=0.75)
axes[1][1].legend(loc='upper right')

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سن </font>
# </h3>

# %%
age_401_urban= data_401_urban['age'].dropna()
age_400_urban= data_400_urban['age'].dropna()
age_99_urban= data_99_urban['age'].dropna()
age_98_urban= data_98_urban['age'].dropna()
age_401_rural= data_98_rural['age'].dropna()
age_400_rural= data_98_rural['age'].dropna()
age_99_rural= data_98_rural['age'].dropna()
age_98_rural= data_98_rural['age'].dropna()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(18, 8))

# 1401_age
axes[0][0].hist(age_401_urban, label='urbun', alpha=.8, edgecolor='black')
axes[0][0].hist(age_401_rural, label='rural', alpha=0.7, edgecolor='black')
axes[0][0].set_title('1401 Ages')
axes[0][0].set_ylabel('number of people')
axes[0][0].grid(axis='y', alpha=0.75)
axes[0][0].legend(loc='upper right')
# 1400_age
axes[0][1].hist(age_400_urban, label='urbun', alpha=.8, edgecolor='black')
axes[0][1].hist(age_400_rural, label='rural', alpha=0.7, edgecolor='black')
axes[0][1].set_title('1400 Ages')
axes[0][1].set_ylabel('number of people')
axes[0][1].grid(axis='y', alpha=0.75)
axes[0][1].legend(loc='upper right')
# 99_age
axes[1][0].hist(age_99_urban, label='urbun', alpha=.8, edgecolor='black')
axes[1][0].hist(age_99_rural, label='rural', alpha=0.7, edgecolor='black')
axes[1][0].set_title('99 Ages')
axes[1][0].set_ylabel('number of people')
axes[1][0].grid(axis='y', alpha=0.75)
axes[1][0].legend(loc='upper right')
# 98_age
axes[1][1].hist(age_98_urban, label='urbun', alpha=.8, edgecolor='black')
axes[1][1].hist(age_98_rural, label='rural', alpha=0.7, edgecolor='black')
axes[1][1].set_title('98 Ages')
axes[1][1].set_ylabel('number of people')
axes[1][1].grid(axis='y', alpha=0.75)
axes[1][1].legend(loc='upper right')

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# بستگی با سرپرست
# </font>
# </h3>

# %%
relation_401_urban= data_401_urban['relation'].dropna()
relation_400_urban= data_400_urban['relation'].dropna()
relation_99_urban= data_99_urban['relation'].dropna()
relation_98_urban= data_98_urban['relation'].dropna()
relation_401_rural= data_98_rural['relation'].dropna()
relation_400_rural= data_98_rural['relation'].dropna()
relation_99_rural= data_98_rural['relation'].dropna()
relation_98_rural= data_98_rural['relation'].dropna()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(18, 8))
fig.tight_layout(pad=9.0)

# 1401_relation
axes[0][0].hist(relation_401_urban, label='urbun', alpha=.8, edgecolor='black')
axes[0][0].hist(relation_401_rural, label='rural', alpha=0.7, edgecolor='black')
axes[0][0].set_title('1401 Relations')
axes[0][0].set_ylabel('number of people')
axes[0][0].grid(axis='y', alpha=0.75)
axes[0][0].legend(loc='upper right')
axes[0][0].tick_params(axis='x', labelrotation = 45)

# 1400_relation
axes[0][1].hist(relation_400_urban, label='urbun', alpha=.8, edgecolor='black')
axes[0][1].hist(relation_400_rural, label='rural', alpha=0.7, edgecolor='black')
axes[0][1].set_title('1400 Relations')
axes[0][1].set_ylabel('number of people')
axes[0][1].grid(axis='y', alpha=0.75)
axes[0][1].legend(loc='upper right')
axes[0][1].tick_params(axis='x', labelrotation = 45)

# 99_relation
axes[1][0].hist(relation_99_urban, label='urbun', alpha=.8, edgecolor='black')
axes[1][0].hist(relation_99_rural, label='rural', alpha=0.7, edgecolor='black')
axes[1][0].set_title('99 Relations')
axes[1][0].set_ylabel('number of people')
axes[1][0].grid(axis='y', alpha=0.75)
axes[1][0].legend(loc='upper right')
axes[1][0].tick_params(axis='x', labelrotation = 45)

# 98_relation
axes[1][1].hist(relation_98_urban, label='urbun', alpha=.8, edgecolor='black')
axes[1][1].hist(relation_98_rural, label='rural', alpha=0.7, edgecolor='black')
axes[1][1].set_title('98 Relations')
axes[1][1].set_ylabel('number of people')
axes[1][1].grid(axis='y', alpha=0.75)
axes[1][1].legend(loc='upper right')
axes[1][1].tick_params(axis='x', labelrotation = 45)

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وضع فعاليت
# </font>
# </h3>

# %%
occupationalst_401_urban= data_401_urban['occupationalst'].dropna()
occupationalst_400_urban= data_400_urban['occupationalst'].dropna()
occupationalst_99_urban= data_99_urban['occupationalst'].dropna()
occupationalst_98_urban= data_98_urban['occupationalst'].dropna()
occupationalst_401_rural= data_98_rural['occupationalst'].dropna()
occupationalst_400_rural= data_98_rural['occupationalst'].dropna()
occupationalst_99_rural= data_98_rural['occupationalst'].dropna()
occupationalst_98_rural= data_98_rural['occupationalst'].dropna()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(18, 8))

# 1401_occupationalst
axes[0][0].hist(occupationalst_401_urban, label='urbun', alpha=.8, edgecolor='black')
axes[0][0].hist(occupationalst_401_rural, label='rural', alpha=0.7, edgecolor='black')
axes[0][0].set_title('1401 Occupationalst')
axes[0][0].set_ylabel('number of people')
axes[0][0].grid(axis='y', alpha=0.75)
axes[0][0].legend(loc='upper right')

# 1400_occupationalst
axes[0][1].hist(occupationalst_400_urban, label='urbun', alpha=.8, edgecolor='black')
axes[0][1].hist(occupationalst_400_rural, label='rural', alpha=0.7, edgecolor='black')
axes[0][1].set_title('1400 Occupationalst')
axes[0][1].set_ylabel('number of people')
axes[0][1].grid(axis='y', alpha=0.75)
axes[0][1].legend(loc='upper right')

# 99_occupationalst
axes[1][0].hist(occupationalst_99_urban, label='urbun', alpha=.8, edgecolor='black')
axes[1][0].hist(occupationalst_99_rural, label='rural', alpha=0.7, edgecolor='black')
axes[1][0].set_title('99 Occupationalst')
axes[1][0].set_ylabel('number of people')
axes[1][0].grid(axis='y', alpha=0.75)
axes[1][0].legend(loc='upper right')

# 98_occupationalst
axes[1][1].hist(occupationalst_98_urban, label='urbun', alpha=.8, edgecolor='black')
axes[1][1].hist(occupationalst_98_rural, label='rural', alpha=0.7, edgecolor='black')
axes[1][1].set_title('98 Occupationalst')
axes[1][1].set_ylabel('number of people')
axes[1][1].grid(axis='y', alpha=0.75)
axes[1][1].legend(loc='upper right')

# %% [markdown]
# <h3 dir=rtl  style="line-height:200%;font-family:vazir">
# <font face="vazir" size=4>
# 2 - ترند هزینه خانوار برای در هر سال برای غذاهاي آماده، هتل و رستوران
# </font>
# </h3>

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# ترند هزینه خانوار برای در هر سال برای غذاهاي آماده
# </font>
# </h3>

# %%
cost_in_urban_401 = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S01')
cost_in_rural_401 = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S01')

# %%
mappings = {
    11111: 'چلوكباب برگ و چنجه',
    11112: 'چلوكباب كوبیده',
    11113: 'چلو خورشت',
    11114: 'آبگوشت',
    11115: 'كباب كوبیده',
    11116: 'كباب برگ و چنجه )بدون برنج(',
    11117: 'جوجهكباب، جوجه سوخاری، ماهی سوخاری، مرغ بریان و نظایر آن',
    11118: 'پیتزا و نظایر آن',
    11119: 'چلو گوشت، چلو مرغ، زرشك پلو با مرغ، لوبیا پلو، باقالا پلو، شیرین پلو، تهچین و نظایر آن',
    11121: 'جگر، دل و قلوه، كله پاچه، سیرابی و نظایر آن',
    11122: 'حلیم، آش و نظایر آن',
    11123: 'ساندویچ سوسیس',
    11124: 'سایر انواع ساندویچ',
    11125: 'سالاد، سیب زمینی سرخ كرده، اسنك',
    11126: 'سمبوسه، فلافل، پاكوره و نظایر آن',
    11127: 'انواع غذاهای كنسرو شده )حلیم بادنجان، لوبیا، خورش قیمه و نظایر آن(',
    11128: 'صبحانه نان و پنیر',
    11129: 'صبحانه تخم مرغ نیمرو',
    11131: 'سایر انواع صبحانه',
    11132: 'چای',
    11133: 'انواع نوشابه و دوغ',
    11134: 'مأالشعیر و دلستر',
    11135: 'انواع آب میوه',
    11136: 'قهوه، نسکافه، شیر كاكائو و ...',
    11137: 'قلیان در خارج از منزل',
    11141: 'انواع نان شیرینی، كیك و بیسکویت',
    11142: 'انواع میوه و كمپوت',
    11143: 'انواع بستنی و فالوده',
    11144: 'چغندرپخته )لبو(، شلغم، سیب زمینی، باقلا پخته، بلال، انواع هرت و نظایر آن',
    11145: 'پفك نمکی و چیپس',
    11146: 'سایر انواع تنقلات مصرف شده در خارج از منزل',
    11147: 'سرویس میز و انعام',
    11148: 'اجرت پخت غذا بدون مواد اولیه',
}

# %%
#urban
urban_result_401 = cost_in_urban_401[(cost_in_urban_401.code > 11110) & (cost_in_urban_401.code < 11149)]
food_trend_401_urban=urban_result_401[['code','value']].groupby("code",as_index = False).sum()
food_trend_401_urban['food_name'] = food_trend_401_urban['code'].map(mappings)

#rural
rural_result = cost_in_rural_401[(cost_in_rural_401.code > 11110) & (cost_in_rural_401.code < 11149)]
food_trend_401_rural=rural_result[['code','value']].groupby("code",as_index = False).sum()
food_trend_401_rural['food_name'] = food_trend_401_rural['code'].map(mappings)


#bar_chart
fig, ax = plt.subplots(1,2, figsize=(18, 8))
ax[0].bar(food_trend_401_urban['food_name'], food_trend_401_urban['value'], color='red')
ax[0].tick_params(axis='x', labelrotation = 90)
ax[0].set_title('Food Trend in 1401 urban')
ax[1].bar(food_trend_401_rural['food_name'], food_trend_401_rural['value'], color='blue')
ax[1].tick_params(axis='x', labelrotation = 90)
ax[1].set_title('Food Trend in 1401 rural')
plt.show()

# %%
cost_in_urban_400 = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S01')
cost_in_rural_400 = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S01')

# %%
#urban
urban_result_400 = cost_in_urban_400[(cost_in_urban_400.code > 11110) & (cost_in_urban_400.code < 11150)]
food_trend_400_urban=urban_result_400[['code','value']].groupby("code",as_index = False).sum()
food_trend_400_urban['food_name'] = food_trend_400_urban['code'].map(mappings)

#rural
rural_result_400 = cost_in_rural_400[(cost_in_rural_400.code > 11110) & (cost_in_rural_400.code < 11149)]
food_trend_400_rural=rural_result_400[['code','value']].groupby("code",as_index = False).sum()
food_trend_400_rural['food_name'] = food_trend_400_rural['code'].map(mappings)

#bar_chart
fig, ax = plt.subplots(1,2, figsize=(18, 8))
ax[0].bar(food_trend_400_urban['food_name'], food_trend_400_urban['value'], color='red')
ax[0].tick_params(axis='x', labelrotation = 90)
ax[0].set_title('Food Trend in 1400 urban')
ax[1].bar(food_trend_400_rural['food_name'], food_trend_400_rural['value'], color='blue')
ax[1].tick_params(axis='x', labelrotation = 90)
ax[1].set_title('Food Trend in 1400 rural')
plt.show()

# %%
cost_in_urban_99 = pd.read_excel('U99.xlsx', sheet_name='U99P3S01')
cost_in_rural_99 = pd.read_excel('R99.xlsx', sheet_name='R99P3S01')

# %%
#urban
urban_result_99 = cost_in_urban_99[(cost_in_urban_99.code > 11110) & (cost_in_urban_99.code < 11150)]
food_trend_99_urban=urban_result_99[['code','value']].groupby("code",as_index = False).sum()
food_trend_99_urban['food_name'] = food_trend_99_urban['code'].map(mappings)

#rural
rural_result_99 = cost_in_rural_99[(cost_in_rural_99.code > 11110) & (cost_in_rural_99.code < 11149)]
food_trend_99_rural = rural_result_99[['code','value']].groupby("code",as_index = False).sum()
food_trend_99_rural['food_name'] = food_trend_99_rural['code'].map(mappings)

#bar_chart
fig, ax = plt.subplots(1,2, figsize=(18, 8))
ax[0].bar(food_trend_99_urban['food_name'], food_trend_99_urban['value'], color='red')
ax[0].tick_params(axis='x', labelrotation = 90)
ax[0].set_title('Food Trend in 1399 urban')
ax[1].bar(food_trend_99_rural['food_name'], food_trend_99_rural['value'], color='blue')
ax[1].tick_params(axis='x', labelrotation = 90)
ax[1].set_title('Food Trend in 1399 rural')
plt.show()

# %%
cost_in_urban_98 = pd.read_excel('U98.xlsx', sheet_name='U1399P3S01')
cost_in_rural_98 = pd.read_excel('R98.xlsx', sheet_name='R1399P3S01')

# %%
#urban
urban_result_98 = cost_in_urban_98[(cost_in_urban_98.code > 11110) & (cost_in_urban_98.code < 11150)]
food_trend_98_urban = urban_result_98[['code','value']].groupby("code",as_index = False).sum()
food_trend_98_urban['food_name'] = food_trend_98_urban['code'].map(mappings)

#rural
rural_result_98 = cost_in_rural_98[(cost_in_rural_98.code > 11110) & (cost_in_rural_98.code < 11149)]
food_trend_98_rural = rural_result_98[['code','value']].groupby("code",as_index = False).sum()
food_trend_98_rural['food_name'] = food_trend_98_rural['code'].map(mappings)

#bar_chart
fig, ax = plt.subplots(1,2, figsize=(18, 8))
ax[0].bar(food_trend_98_urban['food_name'], food_trend_98_urban['value'], color='red')
ax[0].tick_params(axis='x', labelrotation = 90)
ax[0].set_title('Food Trend in 1398 urban')
ax[1].bar(food_trend_98_rural['food_name'], food_trend_98_rural['value'], color='blue')
ax[1].tick_params(axis='x', labelrotation = 90)
ax[1].set_title('Food Trend in 1398 rural')
plt.show()

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# ترند هزینه خانوار در هر سال برای هتل
# </font>
# </h3>

# %%
mappings = {
    11211: 'هزینه پرداختی بابت كرایه اتاق در هتل و متل',
    11212: 'هزینه پرداختی بابت كرایه اتاق در مسافرخانه',
    11213: 'هزینه پرداختی در غیر از هتل، متل و مسافرخانه )نظیر اتاق، چادر، كمپینگ و نظایر آن(',
    11214: 'هزینه خدمات تامین جا در دانشگاهها، مدارس شبانهروزی و سایر موسسات آموزشی',
    11215: 'هزینه خدمات تامین جا برای برگزاری مجلس )تالار، باغ، مسجد و...(',
    11216: 'انعام و دستمزد باربر'
}

# %%
#urban
urban_result_401_hotel = cost_in_urban_401[(cost_in_urban_401.code > 11210) & (cost_in_urban_401.code < 11217)]
hotel_trend_401_urban = urban_result_401_hotel[['code','value']].groupby("code",as_index = False).sum()
hotel_trend_401_urban['name'] = hotel_trend_401_urban['code'].map(mappings)

#rural
rural_result_401_hotel = cost_in_rural_401[(cost_in_rural_401.code > 11210) & (cost_in_rural_401.code < 11217)]
hotel_trend_401_rural = rural_result_401_hotel[['code','value']].groupby("code",as_index = False).sum()
hotel_trend_401_rural['name'] = hotel_trend_401_rural['code'].map(mappings)

#bar_chart
fig, ax = plt.subplots(1,2, figsize=(18, 8))
ax[0].bar(hotel_trend_401_urban['name'], hotel_trend_401_urban['value'], color='red')
ax[0].tick_params(axis='x', labelrotation = 90)
ax[0].set_title('Accommodation Trend in 1401 urban')
ax[1].bar(hotel_trend_401_rural['name'], hotel_trend_401_rural['value'], color='blue')
ax[1].tick_params(axis='x', labelrotation = 90)
ax[1].set_title('Accommodation Trend in 1401 rural')
plt.show()

# %%
#urban
urban_result_400_hotel = cost_in_urban_400[(cost_in_urban_400.code > 11210) & (cost_in_urban_400.code < 11217)]
hotel_trend_400_urban = urban_result_400_hotel[['code','value']].groupby("code",as_index = False).sum()
hotel_trend_400_urban['name'] = hotel_trend_400_urban['code'].map(mappings)

#rural
rural_result_400_hotel = cost_in_rural_400[(cost_in_rural_400.code > 11210) & (cost_in_rural_400.code < 11217)]
hotel_trend_400_rural = rural_result_400_hotel[['code','value']].groupby("code",as_index = False).sum()
hotel_trend_400_rural['name'] = hotel_trend_400_rural['code'].map(mappings)

#bar_chart
fig, ax = plt.subplots(1,2, figsize=(18, 8))
ax[0].bar(hotel_trend_400_urban['name'], hotel_trend_400_urban['value'], color='red')
ax[0].tick_params(axis='x', labelrotation = 90)
ax[0].set_title('Accommodation Trend in 1400 urban')
ax[1].bar(hotel_trend_400_rural['name'], hotel_trend_400_rural['value'], color='blue')
ax[1].tick_params(axis='x', labelrotation = 90)
ax[1].set_title('Accommodation Trend in 1400 rural')
plt.show()

# %%
#urban
urban_result_99_hotel = cost_in_urban_99[(cost_in_urban_99.code > 11210) & (cost_in_urban_99.code < 11217)]
hotel_trend_99_urban = urban_result_99_hotel[['code','value']].groupby("code",as_index = False).sum()
hotel_trend_99_urban['name'] = hotel_trend_99_urban['code'].map(mappings)

#rural
rural_result_99_hotel = cost_in_rural_99[(cost_in_rural_99.code > 11210) & (cost_in_rural_99.code < 11217)]
hotel_trend_99_rural = rural_result_99_hotel[['code','value']].groupby("code",as_index = False).sum()
hotel_trend_99_rural['name'] = hotel_trend_99_rural['code'].map(mappings)

#bar_chart
fig, ax = plt.subplots(1,2, figsize=(18, 8))
ax[0].bar(hotel_trend_99_urban['name'], hotel_trend_99_urban['value'], color='red')
ax[0].tick_params(axis='x', labelrotation = 90)
ax[0].set_title('Accommodation Trend in 1399 urban')
ax[1].bar(hotel_trend_99_rural['name'], hotel_trend_99_rural['value'], color='blue')
ax[1].tick_params(axis='x', labelrotation = 90)
ax[1].set_title('Accommodation Trend in 1399 rural')
plt.show()

# %%
#urban
urban_result_98_hotel = cost_in_urban_98[(cost_in_urban_98.code > 11210) & (cost_in_urban_98.code < 11217)]
hotel_trend_98_urban = urban_result_98_hotel[['code','value']].groupby("code",as_index = False).sum()
hotel_trend_98_urban['name'] = hotel_trend_98_urban['code'].map(mappings)

#rural
rural_result_98_hotel = cost_in_rural_98[(cost_in_rural_98.code > 11210) & (cost_in_rural_98.code < 11217)]
hotel_trend_98_rural = rural_result_98_hotel[['code','value']].groupby("code",as_index = False).sum()
hotel_trend_98_rural['name'] = hotel_trend_98_rural['code'].map(mappings)

#bar_chart
fig, ax = plt.subplots(1,2, figsize=(18, 8))
ax[0].bar(hotel_trend_98_urban['name'], hotel_trend_98_urban['value'], color='red')
ax[0].tick_params(axis='x', labelrotation = 90)
ax[0].set_title('Accommodation Trend in 1398 urban')
ax[1].bar(hotel_trend_98_rural['name'], hotel_trend_98_rural['value'], color='blue')
ax[1].tick_params(axis='x', labelrotation = 90)
ax[1].set_title('Accommodation Trend in 1398 rural')
plt.show()

# %%
#compare food costs in unbun
food_name = food_trend_401_urban['food_name']
food_values = {
    '1401': (food_trend_401_urban['value']),
    '1400': (food_trend_400_urban['value']),
    '1399': (food_trend_99_urban['value']),
    '1398': (food_trend_98_urban['value'])
}

x = np.arange(len(food_name))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(18, 8),layout='constrained')

for attribute, measurement in food_values.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, food_name)
ax.legend(loc='upper left', ncols=4)
# ax.set_ylim(0, 250)

plt.show()

# %%
#compare food costs in unbun
food_name_rural = food_trend_401_rural['food_name']
food_values_rural = {
    '1401': (food_trend_401_rural['value']),
    '1400': (food_trend_400_rural['value']),
    '1399': (food_trend_99_rural['value']),
    '1398': (food_trend_98_rural['value'])
}

x = np.arange(len(food_name_rural))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(18, 8),layout='constrained')

for attribute, measurement in food_values_rural.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, food_name_rural)
ax.legend(loc='upper left', ncols=4)
# ax.set_ylim(0, 250)

plt.show()

# %%
hotel_name = hotel_trend_401_urban['name']
hotel_values = {
    '1401': (hotel_trend_401_urban['value']),
    '1400': (hotel_trend_400_urban['value']),
    '1399': (hotel_trend_99_urban['value']),
    '1398': (hotel_trend_98_urban['value'])
}

x = np.arange(len(hotel_name))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(18, 8),layout='constrained')

for attribute, measurement in hotel_values.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, hotel_name)
ax.legend(loc='upper left', ncols=4)
# ax.set_ylim(0, 250)

plt.show()

# %%
hotel_name_rural = hotel_trend_401_rural['name']
hotel_values_rural = {
    '1401': (hotel_trend_401_rural['value']),
    '1400': (hotel_trend_400_rural['value']),
    '1399': (hotel_trend_99_rural['value']),
    '1398': (hotel_trend_98_rural['value'])
}

x = np.arange(len(hotel_name_rural))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(18, 8),layout='constrained')

for attribute, measurement in hotel_values_rural.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, hotel_name_rural)
ax.legend(loc='upper left', ncols=4)
# ax.set_ylim(0, 250)

plt.show()

# %% [markdown]
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# تست نرمال بودن داده
# </font>
# </h3>

# %%
#use_shapiro_test_to_show_data_is_not_normal

stat, p_value = shapiro(sample(list(age_401_urban),5000))

print(f"Shapiro-Wilk Test Statistic: {stat}")
print(f"p-value: {p_value}")

alpha = 0.05
if p_value > alpha:
    print("The sample looks Gaussian (fail to reject H0)")
else:
    print("The sample does not look Gaussian (reject H0)")
# Out:
# Shapiro-Wilk Test Statistic: 0.9711646437644958
# p-value: 1.3849576640258203e-30
# The sample does not look Gaussian (reject H0)

# %%
#use_methods_to_normal_data

sample_data = age_401_urban.values.reshape(-1, 1)

yeo_johnson_transformed = power_transform(sample_data, method='yeo-johnson')
yeo_johnson_transformed = yeo_johnson_transformed.flatten()

if np.all(sample_data > 0):
    box_cox_transformed, _ = power_transform(sample_data, method='box-cox', standardize=False)
    box_cox_transformed = box_cox_transformed.flatten()
else:
    box_cox_transformed = None
    print("Box-Cox transformation requires all values to be positive. Skipping Box-Cox.")

stat_original, p_value_original = shapiro(sample_data.flatten())
print(f"Original Data: Shapiro-Wilk Test Statistic: {stat_original}, p-value: {p_value_original}")

stat_yeo, p_value_yeo = shapiro(yeo_johnson_transformed)
print(f"Yeo-Johnson Transformed Data: Shapiro-Wilk Test Statistic: {stat_yeo}, p-value: {p_value_yeo}")

if box_cox_transformed is not None:
    stat_box, p_value_box = shapiro(box_cox_transformed)
    print(f"Box-Cox Transformed Data: Shapiro-Wilk Test Statistic: {stat_box}, p-value: {p_value_box}")

def interpret_shapiro(p_value, alpha=0.05):
    if p_value > alpha:
        return "The sample looks Gaussian (fail to reject H0)"
    else:
        return "The sample does not look Gaussian (reject H0)"

print(f"Original Data: {interpret_shapiro(p_value_original)}")
print(f"Yeo-Johnson Transformed Data: {interpret_shapiro(p_value_yeo)}")
if box_cox_transformed is not None:
    print(f"Box-Cox Transformed Data: {interpret_shapiro(p_value_box)}")
# Out:
# Box-Cox transformation requires all values to be positive. Skipping Box-Cox.
# Original Data: Shapiro-Wilk Test Statistic: 0.9724879860877991, p-value: 0.0
# Yeo-Johnson Transformed Data: Shapiro-Wilk Test Statistic: 0.9804197549819946, p-value: 0.0
# Original Data: The sample does not look Gaussian (reject H0)
# Yeo-Johnson Transformed Data: The sample does not look Gaussian (reject H0)
# c:\Users\fatemeh\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning:
#
# p-value may not be accurate for N > 5000.

# %%
# Hypothesis:
# H0: The distributions of both groups are equal.
# H1: The distributions of both groups are not equal.

group1 = age_401_urban
group2 = age_401_rural
stat, p_value = mannwhitneyu(group1, group2)

print(f"Mann-Whitney U Test Statistic: {stat}")
print(f"p-value: {p_value}")

alpha = 0.05
if p_value > alpha:
    print("Fail to reject H0: The distributions of both groups are equal")
else:
    print("Reject H0: The distributions of both groups are not equal")
# Out:
# Mann-Whitney U Test Statistic: 2174808754.5
# p-value: 1.3775815799740656e-44
# Reject H0: The distributions of both groups are not equal
